# %% [markdown]
# # 한글폰트 설치

# %%
# 일단 import 
# %matplotlib inline  

import matplotlib as mpl  # 기본 설정 만지는 용도
import matplotlib.pyplot as plt  # 그래프 그리는 용도
import matplotlib.font_manager as fm  # 폰트 관련 용도

# %% [markdown]
# ## 한글 깨지는 것 확인하기

# %%
# 데이터 준비
import numpy as np

data = np.random.randint(-200, 100, 50).cumsum()
data
# 한글을 넣어놓고 그러보면 깨진다
plt.figure(figsize=(6,4))
plt.plot(range(50), data, 'r')
plt.title('시간별 가격추이')
plt.ylabel('주식가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 44201 (\N{HANGUL SYLLABLE GYEOG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 52628 (\N{HANGUL SYLLABLE CU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44201 (\N{HANGUL SYLLABLE GYEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52628 (\N{HANGUL SYLLABLE CU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82104\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 시스템에 설치된 폰트 확인.

# %%
sys_font=fm.findSystemFonts()
print(f"sys_font number: {len(sys_font)}")
print(sys_font)

font = [f for f in sys_font if 'Nanum' in f]  #나눔폰트찾기
print(f"nanum_font number: {len(font)}")

font
# Out:
# sys_font number: 404
# ['C:\\Windows\\Fonts\\FORTE.TTF', 'C:\\Windows\\Fonts\\NirmalaS.ttf', 'C:\\Windows\\Fonts\\georgiaz.ttf', 'C:\\Windows\\Fonts\\AGENCYR.TTF', 'C:\\Windows\\Fonts\\cambriaz.ttf', 'C:\\Windows\\Fonts\\ARLRDBD.TTF', 'C:\\Windows\\Fonts\\ANTQUAI.TTF', 'C:\\Windows\\Fonts\\HANWing2.ttf', 'C:\\Windows\\Fonts\\PERB____.TTF', 'C:\\Windows\\Fonts\\corbelb.ttf', 'C:\\Windows\\Fonts\\MISTRAL.TTF', 'C:\\Windows\\Fonts\\FRABK.TTF', 'C:\\Windows\\Fonts\\georgiab.ttf', 'C:\\Windows\\Fonts\\BOD_PSTC.TTF', 'C:\\Windows\\Fonts\\bahnschrift.ttf', 'C:\\Windows\\Fonts\\gadugi.ttf', 'C:\\Windows\\Fonts\\calibril.ttf', 'C:\\Windows\\Fonts\\H2GPRM.TTF', 'C:\\Windows\\Fonts\\arialbd.ttf', 'C:\\Windows\\Fonts\\CALISTB.TTF', 'C:\\Windows\\Fonts\\simsun.ttc', 'C:\\Windows\\Fonts\\sylfaen.ttf', 'C:\\Windows\\Fonts\\GOTHICBI.TTF', 'C:\\Windows\\Fonts\\ROCKBI.TTF', 'C:\\Windows\\Fonts\\HANDotumExt.ttf', 'C:\\Windows\\Fonts\\simsunb.ttf', 'C:\\Windows\\Fonts\\HANDotum.ttf', 'C:\\Windows\\Fonts\\RAVIE.TTF', 'C:\\Windows\\Fonts\\LSANSDI.TTF', 'C:\\Windows\\Fonts\\timesbd.ttf', 'C:\\Windows\\Fonts\\BRADHITC.TTF', 'C:\\Windows\\Fonts\\ITCBLKAD.TTF', 'C:\\Windows\\Fonts\\FRAHVIT.TTF', 'C:\\Windows\\Fonts\\batang.ttc', 'C:\\Windows\\Fonts\\HATTEN.TTF', 'C:\\Windows\\Fonts\\H2GTRM.TTF', 'C:\\Windows\\Fonts\\ANT
Windows\\Fonts\\HMFMPYUN.TTF', 'C:\\Windows\\Fonts\\georgiai.ttf', 'C:\\Windows\\Fonts\\FZSTK.TTF', 'C:\\Windows\\Fonts\\LTYPEBO.TTF', 'C:\\Windows\\Fonts\\GIGI.TTF', 'C:\\Windows\\Fonts\\ONYX.TTF', 'C:\\Windows\\Fonts\\FREESCPT.TTF', 'C:\\Windows\\Fonts\\seguibl.ttf', 'C:\\Windows\\Fonts\\verdana.ttf', 'C:\\Windows\\Fonts\\GOUDOSI.TTF', 'C:\\Windows\\Fonts\\constan.ttf', 'C:\\Windows\\Fonts\\seguibli.ttf', 'C:\\Windows\\Fonts\\BOD_I.TTF', 'C:\\Windows\\Fonts\\BRLNSB.TTF', 'C:\\Windows\\Fonts\\WINGDNG3.TTF', 'C:\\Windows\\Fonts\\HANBatang.ttf', 'C:\\Windows\\Fonts\\calibrib.ttf', 'C:\\Windo ...
# nanum_font number: 12
# ['C:\\Users\\miran\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareRoundB.ttf',
#  'C:\\Users\\miran\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquare.ttf',
#  'C:\\Users\\miran\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquare_acR.ttf',
#  'C:\\Users\\miran\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareRoundR.ttf',
#  'C:\\Users\\miran\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareR.ttf',
#  'C:\\Users\\miran\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquare_acL.ttf',
#  'C:\\Users\\miran\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareRoundL.ttf',
#  'C:\\Users\\miran\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareRoundEB.ttf',
#  'C:\\Users\\miran\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareEB.ttf',
#  'C:\\Users\\miran\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareB.ttf',
#  'C:\\Users\\miran\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareL.ttf',
#  'C:\\Users\\miran\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquare_0.ttf']

# %%
font = [f for f in sys_font if 'malgun' in f]  #맑은폰트찾기
print(f"Malgun_font number: {len(font)}")
font
# Out:
# Malgun_font number: 3
# ['C:\\Windows\\Fonts\\malgunsl.ttf',
#  'C:\\Windows\\Fonts\\malgun.ttf',
#  'C:\\Windows\\Fonts\\malgunbd.ttf']

# %% [markdown]
# ## matplotlib 글꼴 패밀리 검색

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

#메모리 상에 현재 설정되어 있는 폰트 패밀리 이름
font_family = plt.rcParams['font.family']
font_family
# Out:
# ['sans-serif']

# %%
#맷플랏립의 기본 글꼴-> 한글표현 안 되겠쥬
fm.FontManager().defaultFont
# Out:
# {'ttf': 'C:\\Python\\python310\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf',
#  'afm': 'C:\\Python\\python310\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\pdfcorefonts\\Helvetica.afm'}

# %%
# matplotlib 한글 폰트 오류 문제 해결 

import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

#폰트파일위치 지정해서 설정
font_path = 'C:\\Users\\miran\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquare.ttf'
font_name = fm.FontProperties(fname=font_path).get_name()

#폰트 설정
plt.rc('font', family=font_name)

# 마이너스 깨짐 현상 해결
plt.rcParams['axes.unicode_minus'] = False

# matplotlib 폰트 패밀리 출력
plt.rcParams['font.family']
# Out:
# ['NanumSquare_ac']

# %%
# 데이터 준비
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl  # 기본 설정 만지는 용도

data = np.random.randint(-200, 100, 50).cumsum()
data

## 폰트 설정 및 마이너스 부호 설정
#plt.rc('font', family='NanumSquare') #나눔 글꼴로 설정
#plt.rc('font', family='AppleGothic') #맥

# 이거 두 개 사용
plt.rc('font', family='Malgun Gothic') #맑은 고딕으로 설정
plt.rcParams['axes.unicode_minus'] = False #부호


# 한글을 넣어놓고 그러보면 깨진다
plt.figure(figsize=(6,4))
plt.plot(range(50), data, 'r')
plt.title('시간별 가격추이')
plt.ylabel('주식가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')
