# %% [markdown]
# # BeautifulSoup 사용방법

# %%
# !pip install beautifulSoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: beautifulSoup4 in c:\users\82104\appdata\roaming\python\python310\site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\82104\appdata\roaming\python\python310\site-packages (from beautifulSoup4) (2.4.1)
# WARNING: Ignoring invalid distribution -illow (c:\users\82104\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\82104\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\82104\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\82104\appdata\roaming\python\python310\site-packages)

# %%
# bs4라는 패키지로부터 BeautifulSoup라는 모듈을 임포트
from bs4 import BeautifulSoup

# %%
html = """
<html>
    <body>
        <h1 id='title'>[1]크롤링이란?</h1>
        <p class='cssstyle'>웹페이지에서 필요한 데이터를 추출하는 것</p>
        <p id='body' align='center'>파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>
        <a href = 'http://www.facebook.com'> 바로가기 </a>
        <ul id="aladin_list">
            <li class="cssstyle" id='start'>[국내도서]신나는 파이썬</li>
            <li class="course" id='start'>[국내도서] 혼자 공부하는 파이썬</li>
            <li class="course" id='end'><a href="https://www.aladin.co.kr">[국내도서] Effective Python 2nd 이펙티브 파이썬 : 파이썬 코딩의 기술 </a></li>
        </ul>
        <img src='https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Dumbo-hires_%28cropped%29.jpg/330px-Dumbo-hires_%28cropped%29.jpg'>
    </body>
</html>
"""

# %%
# BeautifulSoup 인스턴스 생성. 두번째 매개변수는 분석할 분석기(parser)의 종류.
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# <html>
# <body>
# <h1 id="title">[1]크롤링이란?</h1>
# <p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것</p>
# <p align="center" id="body">파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>
# <a href="http://www.facebook.com"> 바로가기 </a>
# <ul id="aladin_list">
# <li class="cssstyle" id="start">[국내도서]신나는 파이썬</li>
# <li class="course" id="start">[국내도서] 혼자 공부하는 파이썬</li>
# <li class="course" id="end"><a href="https://www.aladin.co.kr">[국내도서] Effective Python 2nd 이펙티브 파이썬 : 파이썬 코딩의 기술 </a></li>
# </ul>
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Dumbo-hires_%28cropped%29.jpg/330px-Dumbo-hires_%28cropped%29.jpg"/>
# </body>
# </html>

# %% [markdown]
# ## 태그 선택
#
# *  태그 이름이 tag1인 html요소를 리스트 형태로 모두 반환한다.
# ```python
#     soup.select('tag1')
# ```
# * 태그 이름이 tag1인html요소중 첫번째 요소만 반환한다.
# ```python
#    soup.select_one('tag1')
# ```

# %%
# <body> 태그를 입력
soup.select('body')  # 리스트 형태로 반환
# Out:
# [<body>
#  <h1 id="title">[1]크롤링이란?</h1>
#  <p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것</p>
#  <p align="center" id="body">파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>
#  <a href="http://www.facebook.com"> 바로가기 </a>
#  <ul id="aladin_list">
#  <li class="cssstyle" id="start">[국내도서]신나는 파이썬</li>
#  <li class="course" id="start">[국내도서] 혼자 공부하는 파이썬</li>
#  <li class="course" id="end"><a href="https://www.aladin.co.kr">[국내도서] Effective Python 2nd 이펙티브 파이썬 : 파이썬 코딩의 기술 </a></li>
#  </ul>
#  <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Dumbo-hires_%28cropped%29.jpg/330px-Dumbo-hires_%28cropped%29.jpg"/>
#  </body>]

# %%
# p 태그 요소 리스트로 반환
soup.select('p')
# Out:
# [<p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것</p>,
#  <p align="center" id="body">파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>]

# %%
# 첫 번째 p 태그 요소 반환
soup.select_one('p')
# Out:
# <p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것</p>

# %% [markdown]
# ## 하위 태그 선택
#
# * 바로 아래 자식요소만 선택합니다.
# * '>' 를 사용합니다.
# ```python
#     soup.select('tag1 > tag2')
# ```
#
# * 길이가 너무 긴 경우 중간 생략하고 하위 요소를 선택합니다.
# * ' ' 공백을 사용합니다.
# ```python
#     soup.select('tag1 tag2')
# ```

# %%
soup.select('body > p')
# Out:
# [<p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것</p>,
#  <p align="center" id="body">파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>]

# %%
soup.select('ul > li')
# Out:
# [<li class="cssstyle" id="start">[국내도서]신나는 파이썬</li>,
#  <li class="course" id="start">[국내도서] 혼자 공부하는 파이썬</li>,
#  <li class="course" id="end"><a href="https://www.aladin.co.kr">[국내도서] Effective Python 2nd 이펙티브 파이썬 : 파이썬 코딩의 기술 </a></li>]

# %%
soup.select('ul li')
# Out:
# [<li class="cssstyle" id="start">[국내도서]신나는 파이썬</li>,
#  <li class="course" id="start">[국내도서] 혼자 공부하는 파이썬</li>,
#  <li class="course" id="end"><a href="https://www.aladin.co.kr">[국내도서] Effective Python 2nd 이펙티브 파이썬 : 파이썬 코딩의 기술 </a></li>]

# %% [markdown]
# ## css class이름으로 검색
# * **'.클래스이름'** 으로 검색한다.
# * class이름 앞에 점(.)을 사용해야 한다.
# ```python
#     soup.select('.class1')
#     soup.select_one('.class1')
# ```

# %%
soup.select('.cssstyle')
# Out:
# [<p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것</p>,
#  <li class="cssstyle" id="start">[국내도서]신나는 파이썬</li>]

# %%
soup.select('p.cssstyle')
# Out:
# [<p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것</p>]

# %%
soup.select('.course')
# Out:
# [<li class="course" id="start">[국내도서] 혼자 공부하는 파이썬</li>,
#  <li class="course" id="end"><a href="https://www.aladin.co.kr">[국내도서] Effective Python 2nd 이펙티브 파이썬 : 파이썬 코딩의 기술 </a></li>]

# %%
soup.select('li.course')
# Out:
# [<li class="course" id="start">[국내도서] 혼자 공부하는 파이썬</li>,
#  <li class="course" id="end"><a href="https://www.aladin.co.kr">[국내도서] Effective Python 2nd 이펙티브 파이썬 : 파이썬 코딩의 기술 </a></li>]

# %% [markdown]
# ## id 이름으로 검색
# * **#id이름** 으로 검색
# * id 값은 중복되지 않은 유일한 값이다.
# * 찾고자 하는 태그에 id값이 있다면 더 쉽게 검색 가능하다.
# ```python
#     soup.select('#id1')
#     soup.selec_one('#id1')
# ```

# %%
soup.select('li#end')
# Out:
# [<li class="course" id="end"><a href="https://www.aladin.co.kr">[국내도서] Effective Python 2nd 이펙티브 파이썬 : 파이썬 코딩의 기술 </a></li>]

# %% [markdown]
# ## 태그사이의 문자 추출
# ```html
# <h1 id='title'>[1]크롤링이란?</h1>
# ```
# * 태그사이의 문자열 추출
# * .get_text() 또는 .text 를 사용

# %%
soup.select_one('p.cssstyle').get_text()
# Out:
# '웹페이지에서 필요한 데이터를 추출하는 것'

# %%
soup.select_one('p.cssstyle').text
# Out:
# '웹페이지에서 필요한 데이터를 추출하는 것'

# %%
# soup.select('p.cssstyle').text : 리스트 안에 있는 텍스트를 부르는 것.
# 리스트에 .text라는 함수가 있나? -> 없음 그래서 아래처럼 슬라이싱을 해서 추출해야 함.

soup.select('p.cssstyle')[0].text
# Out:
# '웹페이지에서 필요한 데이터를 추출하는 것'

# %%
soup.select_one('ul').text
# Out:
# '\n[국내도서]신나는 파이썬\n[국내도서] 혼자 공부하는 파이썬\n[국내도서] Effective Python 2nd 이펙티브 파이썬 : 파이썬 코딩의 기술 \n'

# %%
txt = soup.select_one('ul').text
txt
# Out:
# '\n[국내도서]신나는 파이썬\n[국내도서] 혼자 공부하는 파이썬\n[국내도서] Effective Python 2nd 이펙티브 파이썬 : 파이썬 코딩의 기술 \n'

# %%
print(txt)
# Out:
# [국내도서]신나는 파이썬
# [국내도서] 혼자 공부하는 파이썬
# [국내도서] Effective Python 2nd 이펙티브 파이썬 : 파이썬 코딩의 기술

# %% [markdown]
# ## 태그의 속성값 가져오기
# ```html
# <a href="https://www.aladin.co.kr">[국내도서] 혼자 공부하는 파이썬</a>
# <img src="/assets/img/octopus.jpg" width="200px">
# ```
#
# * 이미지나 하이퍼링크에 대한 정보는 태그의 속성에 들어있다.
# * 태그의 속성값 추출해야한다.
# * item['속성이름']
# * item.get('속성이름')

# %%
atag = soup.select_one('a')
atag
# Out:
# <a href="http://www.facebook.com"> 바로가기 </a>

# %%
#attribute 값 가져오기
atag['href']
# Out:
# 'http://www.facebook.com'

# %%
atag.get('href')
# Out:
# 'http://www.facebook.com'

# %%
# 이미지 태그 추출
imgtag = soup.select_one('img')
imgtag['src']
# Out:
# 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Dumbo-hires_%28cropped%29.jpg/330px-Dumbo-hires_%28cropped%29.jpg'

# %%
# 알라딘 추출
litag = soup.select_one('li > a')
litag['href']
# Out:
# 'https://www.aladin.co.kr'

# %%
import urllib.request
urllib.request.urlretrieve(imgtag, 'iamge.jpg')
print('다운로드 성공')

# %%
soup.select_one('h1').text
# Out:
# '[1]크롤링이란?'

# %%
soup.select_one('p.cssstyle').text
# Out:
# '웹페이지에서 필요한 데이터를 추출하는 것'
